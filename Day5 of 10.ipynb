# %% [markdown]
# # Day 5 : Data Loading and Manipulation and Visulatiozation

# %% [markdown]
# ### You can use the following liberaries for your assignment:
# > Numpy, Pandas, Matplotlib, Seaborn, LASIO, Welly

# %% [markdown]
# ## Kindly load the las file of Exported.csv file from the data folder
# ## Perform the below Tasks:
#
# >1. Investigate the component of the data file (number of columns , numbers of observations, Null values, normal statistics)
# 2. Plot the null values as bars
# 3. Fill in null values using three different methods.
# 4. Create three facies Log for with 3 different scenarios.
# 5. Plot the three Facies scenarios vs Depth

# %%
# !pip install lasio
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\hp\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import lasio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
F02_1 = lasio.read(r"F:\GeoML-2\GeoML-2.0\10DaysChallenge\Dutch_F3_Logs\F02-1_logs.las")

# %%
df = F02_1.df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 9680 entries, 48.0 to 1499.8501
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RHOB    8253 non-null   float64
#  1   DT      9680 non-null   float64
#  2   GR      9666 non-null   float64
#  3   AI      9680 non-null   float64
#  4   AI_REL  9680 non-null   float64
#  5   PHIE    4906 non-null   float64
# dtypes: float64(6)
# memory usage: 529.4 KB

# %%
df.isnull().sum().plot(kind = 'bar', title = 'Missing Values Comparison', figsize=(20,6))
# Out:
# <AxesSubplot:title={'center':'Missing Values Comparison'}>

# %%
df_max= df.copy()
df_1=df
df_2=df
df_mean= df_1.copy()
df_min= df_2.copy()
df_copied=df

# %%
df_max['RHOB']=df_max['RHOB'].fillna(df_max['RHOB'].max())
df_max['GR']=df_max['GR'].fillna(df_max['GR'].max())
df_max['PHIE']=df_max['PHIE'].fillna(df_max['PHIE'].max())
display('after filling nans',df_max)
# Out:
# 'after filling nans'
#                 RHOB        DT        GR          AI       AI_REL   PHIE
# DEPTH
# 48.0000    2346.6292  524.0485  129.1773  3820257.00    -455.6956  0.709
# 48.1500    2346.6292  524.0410  129.1773  3820311.75    -455.6956  0.709
# 48.3000    2346.6292  524.0336  129.1773  3820366.25    -455.6956  0.709
# 48.4500    2346.6292  524.0262  129.1773  3820419.75    -455.6956  0.709
# 48.6000    2346.6292  524.0190  129.1773  3820472.25    -455.6956  0.709
# ...              ...       ...       ...         ...          ...    ...
# 1499.2500  1787.5444  532.1727   27.6273  3359011.00 -239115.9375  0.709
# 1499.4000  1814.1691  534.8610   28.5281  3391772.00 -239115.9375  0.709
# 1499.5500  1861.6497  537.1902   28.5813  3465524.00 -239115.9375  0.709
# 1499.7001  1880.3978  537.2630   28.5813  3499957.75 -239115.9375  0.709
# 1499.8501  1856.3350  537.3831   27.9759  3454404.00 -212640.7031  0.709
#
# [9680 rows x 6 columns]

# %%
df_mean['RHOB']=df_mean['RHOB'].fillna(df_mean['RHOB'].mean())
df_mean['GR']=df_mean['GR'].fillna(df_mean['GR'].mean())
df_mean['PHIE']=df_mean['PHIE'].fillna(df_mean['PHIE'].mean())
display('after filling nans',df_mean)
# Out:
# 'after filling nans'
#                   RHOB        DT         GR          AI       AI_REL      PHIE
# DEPTH
# 48.0000    1975.091074  524.0485  46.613531  3820257.00    -455.6956  0.304522
# 48.1500    1975.091074  524.0410  46.613531  3820311.75    -455.6956  0.304522
# 48.3000    1975.091074  524.0336  46.613531  3820366.25    -455.6956  0.304522
# 48.4500    1975.091074  524.0262  46.613531  3820419.75    -455.6956  0.304522
# 48.6000    1975.091074  524.0190  46.613531  3820472.25    -455.6956  0.304522
# ...                ...       ...        ...         ...          ...       ...
# 1499.2500  1787.544400  532.1727  27.627300  3359011.00 -239115.9375  0.304522
# 1499.4000  1814.169100  534.8610  28.528100  3391772.00 -239115.9375  0.304522
# 1499.5500  1861.649700  537.1902  28.581300  3465524.00 -239115.9375  0.304522
# 1499.7001  1880.397800  537.2630  28.581300  3499957.75 -239115.9375  0.304522
# ...

# %%
df_min['RHOB']=df_min['RHOB'].fillna(df_min['RHOB'].min())
df_min['GR']=df_min['GR'].fillna(df_min['GR'].min())
df_min['PHIE']=df_min['PHIE'].fillna(df_min['PHIE'].min())
display('after filling nans',df_min)
# Out:
# 'after filling nans'
#                 RHOB        DT       GR          AI       AI_REL    PHIE
# DEPTH
# 48.0000    1350.4447  524.0485   1.3392  3820257.00    -455.6956  0.2039
# 48.1500    1350.4447  524.0410   1.3392  3820311.75    -455.6956  0.2039
# 48.3000    1350.4447  524.0336   1.3392  3820366.25    -455.6956  0.2039
# 48.4500    1350.4447  524.0262   1.3392  3820419.75    -455.6956  0.2039
# 48.6000    1350.4447  524.0190   1.3392  3820472.25    -455.6956  0.2039
# ...              ...       ...      ...         ...          ...     ...
# 1499.2500  1787.5444  532.1727  27.6273  3359011.00 -239115.9375  0.2039
# 1499.4000  1814.1691  534.8610  28.5281  3391772.00 -239115.9375  0.2039
# 1499.5500  1861.6497  537.1902  28.5813  3465524.00 -239115.9375  0.2039
# 1499.7001  1880.3978  537.2630  28.5813  3499957.75 -239115.9375  0.2039
# 1499.8501  1856.3350  537.3831  27.9759  3454404.00 -212640.7031  0.2039
#
# [9680 rows x 6 columns]

# %%
def shale_1(A):
    return 'SHALE' if A >=50 else 'SAND'

    
df_copied['Shale/SD']= df_copied['GR'].apply(shale)
df_copied.sample(5)
# Out:
#              RHOB        DT       GR          AI       AI_REL    PHIE Shale/SD
# DEPTH
# 621.30  1949.4956  606.0524  39.5479  3216664.25 -453036.3125  0.4378     SAND
# 853.05  2214.0579  461.2720  47.9893  4799955.00  -17363.6211  0.2724     SAND
# 573.15  2094.3120  520.8273  72.9106  4021163.25  -87512.6562  0.3473    SHALE
# 952.95  2191.6001  423.6801  51.3214  5172770.50   67160.4922  0.2865    SHALE
# 642.30  2053.8457  517.8945  79.8589  3966150.50  119848.7109  0.3726    SHALE

# %%
def shale_2(A):
    return 'SHALE' if A <=0.1  else 'SAND'

    
df_copied['Shale/SD_2']= df_copied['PHIE'].apply(shale_2)
df_copied.sample(5)
# Out:
#                 RHOB        DT       GR          AI       AI_REL    PHIE  \
# DEPTH
# 854.8500   2236.8455  453.3512  53.6889  4934059.00  -24007.0645  0.2582
# 677.4000   2146.1128  533.5899  85.0138  4022026.50 -120205.4375  0.3149
# 1051.8000  2189.3728  433.6406  52.6489  5048927.00 -365484.8750  0.2879
# 1331.8501  1857.3341  502.9318  59.7216  3693020.00  179107.8281     NaN
# 597.3000   1767.8665  542.6324  41.3868  3257946.25 -256046.9062  0.5513
#
#           Shale/SD Shale/SD_2
# DEPTH
# 854.8500      SAND       SAND
# 677.4000      SAND       SAND
# 1051.8000     SAND       SAND
# 1331.8501     SAND       SAND
# 597.3000      SAND       SAND

# %%
def shale_3(A):
    return 'SHALE' if A >=2000  else 'SAND'

    
df_copied['Shale/SD_3']= df_copied['RHOB'].apply(shale_3)
df_copied.sample(5)
# Out:
#                 RHOB        DT       GR          AI       AI_REL    PHIE  \
# DEPTH
# 1058.1001  2293.2212  392.1272  68.6415  5848171.50  190371.3750  0.2230
# 388.9500   1372.2408  534.4232  21.6119  2567705.25  -89789.7500     NaN
# 307.3500   1941.8397  526.0316  20.8190  3691488.75  396516.6250     NaN
# 1062.0000  2251.7190  399.1373  66.9840  5641619.50  244738.2656  0.2489
# 273.6000   1496.1669  512.9461  19.0034  2916811.00 -433851.2500     NaN
#
#           Shale/SD Shale/SD_2 Shale/SD_3
# DEPTH
# 1058.1001     SAND       SAND      SHALE
# 388.9500      SAND       SAND       SAND
# 307.3500      SAND       SAND       SAND
# 1062.0000     SAND       SAND      SHALE
# 273.6000      SAND       SAND       SAND
